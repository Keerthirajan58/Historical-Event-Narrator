# %% [markdown]
# # 🧠 Historical Event Narrator — Initial Exploration
# This is a lightweight notebook to verify the environment setup for the project.
#
# ✅ Checks:
# - Imports core libraries
# - Verifies torch version and GPU availability
# - Confirms dataset folder structure

# %%
import torch, os
print('Torch version:', torch._version_)
print('GPU available:', torch.cuda.is_available())
print('\nProject folders:')
for folder in ['data', 'src', 'notebooks']:
    print(f' - {folder}:', os.path.exists(folder))
